# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import re
from LAC import LAC
from gensim.models import Word2Vec
# Out:
# D:\software\anaconda\envs\nlp\lib\site-packages\scipy\sparse\sparsetools.py:21: DeprecationWarning: `scipy.sparse.sparsetools` is deprecated!
# scipy.sparse.sparsetools is a private module for scipy.sparse, and should not be used.
#   _deprecated()
# D:\software\anaconda\envs\nlp\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
##########################################################################
def stopwordslist():
    '''
    导入停词表文件
    '''
    stopwords = [line.strip() for line in open('停用词表全.txt',encoding='UTF-8').readlines()]
    return stopwords

##########################################################################
lac_seg = LAC(mode = 'seg')

def seg_text(sentence):
    '''
    对text进行分词（百度lac）
    '''
    seg_t = lac_seg.run(sentence)
    stopwords = stopwordslist()
    outstr = []
    for i in seg_t:
        if i not in stopwords and len(i)>1:
            outstr.append(i)
    return outstr

##########################################################################
def word_lac(text):  
    '''
    词性标注并筛选（jieba）
    '''
    stopwords = stopwordslist()
    r = jieba.posseg.cut(text)
    a = []
    for w in r:
        #if w.flag in ['n','ns','nr','nz'] and w.word not in stopwords and len(w.word)>1:
        if w.flag in ['n','ns','nr','nz','vn'] and w.word not in stopwords and len(w.word)>1:
            a.append(w.word)
        else:
            pass
    return a

##########################################################################
lac_lac = LAC(mode='lac')
def lac_text_baidu(sentence,tag_list):
    '''
    词性标注并筛选（百度lac）
    '''
    stopwords = stopwordslist()
#    lac.load_customization('mydict.txt')
    lac_t = lac_lac.run(sentence)
    data = {'word':lac_t[0],'tag':lac_t[1]}
    df = pd.DataFrame(data)
    df1 = df['word'].loc[df['tag'].isin(tag_list)]
    outstr = []
    for i in df1:
        if i not in stopwords and len(i ) >1:
            outstr.append(i)
    return outstr
# Out:
# D:\software\anaconda\envs\nlp\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <>:17: DeprecationWarning: invalid escape sequence \S
# <>:19: DeprecationWarning: invalid escape sequence \[
# <>:51: DeprecationWarning: invalid escape sequence \S
# <>:53: DeprecationWarning: invalid escape sequence \[
# <>:17: DeprecationWarning: invalid escape sequence \S
# <>:19: DeprecationWarning: invalid escape sequence \[
# <>:51: DeprecationWarning: invalid escape sequence \S
# <>:53: DeprecationWarning: invalid escape sequence \[
# <ipython-input-2-0e80fae6203e>:17: DeprecationWarning: invalid escape sequence \S
#   text = re.sub(u"#\S*?的微博视频|:\S*?的微博视频", ' ', text)
# ...

# %%
df = pd.read_csv(r'D:\datasets\data test\weibo_cluster_clean.csv',encoding = 'utf-8')                         #encoding
df.columns = ['order','user_id','content','clean_content','word']
df
# Out:
#            order     user_id  \
# 0              0  6303175632
# 1              1  6303175632
# 2              2  6303175632
# 3              3  6303175632
# 4              4  6303175632
# ...          ...         ...
# 1020807  1020807  2598556533
# 1020808  1020808  2598556533
# 1020809  1020809  2598556533
# 1020810  1020810  6316807048
# 1020811  1020811  6303175632
#
#                                                    content  \
# 0                                                #泰式芒芒咖喱虾#
# 1                                                #垃圾桶里的母爱#
# 2                                       #女孩花光积蓄买房就能带来安全感吗#
# 3                                               #替我举手机的男生#
# 4                                             #居然对一颗玉米心动了#
# ...                                                    ...
# 1020807  村里新建饮料厂，自家民房成违建#违章建筑 #民房 #民生 ##快手# @快手 河南百姓315...
# 1020808      #致敬军人 #爱国拥军传递正能量 #为人民子弟兵点赞 ##快手# @快手 小北京的快手视频
# 1020809  吴孟超院士告别仪式现场：市民向院士遗体鞠躬 齐喊“吴老走好” ##快手# @快手 我们视频的...
# ...

# %%
df = df[:600000]
df
# Out:
#          order     user_id                                            content  \
# 0            0  6303175632                                          #泰式芒芒咖喱虾#
# 1            1  6303175632                                          #垃圾桶里的母爱#
# 2            2  6303175632                                 #女孩花光积蓄买房就能带来安全感吗#
# 3            3  6303175632                                         #替我举手机的男生#
# 4            4  6303175632                                       #居然对一颗玉米心动了#
# ...        ...         ...                                                ...
# 599995  599995  5685451982                                              有回报就好
# 599996  599996  5925575919                    我好喜欢这几只猫的睡姿，真的太可爱了吧！好想亲一亲！ 微博视频
# 599997  599997  5925575919               我服了，我的电脑整成这德行，给我行行好吧！这几天水逆呀！ 大连 显示地图
# 599998  599998  7508925167                                          今晚送瘟神送走kd
# 599999  599999  5925575919  #吴亦凡 等你超过我#吴亦凡六一儿童节快乐呀！这样非常有意义的一天，你也给孩子们上了一节课，...
#
# ...

# %%
from gensim.models import fasttext,word2vec
import logging 

#输出日志
logging.basicConfig(format='%(asctime)s: %(levelname)s: %(message)s',level=logging.INFO)
# Out:
# D:\software\anaconda\envs\nlp\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# train a bigram detector 
from gensim.models import Phrases,Word2Vec
bigram_trans = Phrases(df['word'])

model_word = Word2Vec(bigram_trans[df['word']],min_count=1,vector_size=100,epochs=200)
# Out:
# 2021-07-16 13:56:34,311: INFO: collecting all words and their counts
# 2021-07-16 13:56:34,312: INFO: PROGRESS: at sentence #0, processed 0 words and 0 word types
# 2021-07-16 13:56:34,490: INFO: PROGRESS: at sentence #10000, processed 236503 words and 20272 word types
# 2021-07-16 13:56:34,686: INFO: PROGRESS: at sentence #20000, processed 501101 words and 30235 word types
# 2021-07-16 13:56:34,877: INFO: PROGRESS: at sentence #30000, processed 756340 words and 38277 word types
# 2021-07-16 13:56:35,084: INFO: PROGRESS: at sentence #40000, processed 1032188 words and 44043 word types
# 2021-07-16 13:56:35,280: INFO: PROGRESS: at sentence #50000, processed 1285935 words and 49733 word types
# 2021-07-16 13:56:35,467: INFO: PROGRESS: at sentence #60000, processed 1527611 words and 55080 word types
# 2021-07-16 13:56:35,680: INFO: PROGRESS: at sentence #70000, processed 1794706 words and 60966 word types
# ...

# %%
from sklearn.cluster import MiniBatchKMeans
from sklearn.metrics import silhouette_samples,silhouette_score

def doc_vec(list_of_docs,model):
    feature = []
    for tokens in list_of_docs:
        zero_vector = np.zeros(model.vector_size)
        vectors = []
        for token in tokens:
            if token in model.wv:
                try:
                    vectors.append(model.wv[token])
                except KeyError:
                    continue
        if vectors:
            vectors = np.asarray(vectors)
            avg_vec = vectors.mean(axis=0)
            feature.append(avg_vec)
        else:
            feature.append(zero_vector)
    return feature


def mbkmeans_clusters(
	X, 
    k, 
    mb, 
    print_silhouette_values, 
):
    """
    Generate clusters and print Silhouette metrics using MBKmeans

    Args:
        X: Matrix of features.
        k: Number of clusters.
        mb: Size of mini-batches.
        print_silhouette_values: Print silhouette values per cluster.

    Returns:
        Trained clustering model and labels based on X.
    """
    label=[]
    km = MiniBatchKMeans(n_clusters=k, batch_size=mb, random_state=2).fit(X)
    print(f"For n_clusters = {k}")
    print(f"Silhouette coefficient: {silhouette_score(X, km.labels_):0.2f}")
    print(f"Inertia:{km.inertia_}")

    if print_silhouette_values:
        sample_silhouette_values = silhouette_samples(X, km.labels_)
        print(f"Silhouette values:")
        silhouette_values = []
        for i in range(k):
            cluster_silhouette_values = sample_silhouette_values[km.labels_ == i]
            silhouette_values.append(
                (
                    i,
                    cluster_silhouette_values.shape[0],
                    cluster_silhouette_values.mean(),
                    cluster_silhouette_values.min(),
                    cluster_silhouette_values.max(),
                )
            )
        silhouette_values = sorted(
            silhouette_values, key=lambda tup: tup[2], reverse=True
        )
        for s in silhouette_values:
            label.append(s[0])
            print(
                f"    Cluster {s[0]}: Size:{s[1]} | Avg:{s[2]:.2f} | Min:{s[3]:.2f} | Max: {s[4]:.2f}"
            )
    return km, km.labels_, label

# %%
docVec = doc_vec(df['word'],model=model_word)
clustering,cluster_labels,Labels = mbkmeans_clusters(X=docVec,k=80,mb=500,print_silhouette_values=True)
data = {'user_id':df['user_id'],'content':df['content'],'word':df['word'],'cluster_label':cluster_labels}

df_clusters = pd.DataFrame(data,columns=['user_id','content','word','cluster_label'])
# Out:
# D:\software\anaconda\envs\nlp\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# For n_clusters = 80
# Silhouette coefficient: 0.07
# Inertia:14784898.466332784
# Silhouette values:
#     Cluster 70: Size:12082 | Avg:1.00 | Min:0.02 | Max: 1.00
#     Cluster 28: Size:1587 | Avg:0.94 | Min:0.11 | Max: 0.97
#     Cluster 45: Size:4683 | Avg:0.94 | Min:0.07 | Max: 0.96
#     Cluster 19: Size:14727 | Avg:0.87 | Min:0.01 | Max: 0.91
#     Cluster 32: Size:2696 | Avg:0.82 | Min:0.05 | Max: 0.89
#     Cluster 17: Size:7139 | Avg:0.60 | Min:-0.01 | Max: 0.71
#     Cluster 64: Size:1203 | Avg:0.57 | Min:0.01 | Max: 0.71
#     Cluster 43: Size:954 | Avg:0.53 | Min:-0.12 | Max: 0.74
# ...

# %%
df_clusters_sort = df_clusters
df_clusters_sort.index = df_clusters_sort['cluster_label']   
df_clusters_sort = df_clusters_sort.loc[Labels]
df_clusters_sort = df_clusters_sort.reset_index(drop=True)
df_clusters_sort
#    将帖子按照Labels进行排序
#    Labels--按照轮廓系数大小排序的聚类标签
# Out:
# D:\software\anaconda\envs\nlp\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#            user_id                                            content  \
# 0       3608343497                     Nooooooooooooooooooooooooo无法接受
# 1       6033700029                            种草了！今年新尝试的酒No.1 西安 显示地图
# 2       6047334667                                                 Nn
# 3       6204651010                              nene简直我本人：可以再一遍吗！超喜欢！
# 4       1856222514                                          一半机会没New啊
# ...            ...                                                ...
# 599995  2758876241                                   你哭起来像刘亦菲，不哭像范冰冰。
# ...

# %%
df_clusters_sort_68 = df_clusters_sort[df_clusters_sort['cluster_label']==61]
df_clusters_sort_68.head(40)
#  查看某特定聚类标签对应的文本内容
# Out:
# D:\software\anaconda\envs\nlp\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#            user_id                                            content  \
# 159477  6181540888                              还有什么是比等外卖更心急的事？[doge]
# 159478  5680321305                                     郝富申先生，请问哪部剧先上?
# 159479  2744309135                        #今天是甄嬛生日#娘娘生日快乐[爱你][爱你][爱你]
# 159480  1799542237                                    诚邀您欣赏 呆瓜和他的老婆孩子
# 159481  1799542237  满载而归[奥特曼][奥特曼] 幸哥名言：老婆开心我就开心 那么具体怎么让老婆开心呢 带她吃带...
# 159482  6244456142                         #撸猫被老婆孩子发现了#c 杭州·西溪北苑 显示地图
# 159483  6966924941                                             像个包租婆了
# ...

# %%
from itertools import chain

dict = {'label':Labels}
word = pd.DataFrame(dict)
word['word']=''

n=0
for i in Labels:
    df = df_clusters_sort[df_clusters_sort['cluster_label']==i]
    df_list = df['word'].tolist()
    df_list = list(chain.from_iterable(df_list))
    word['word'][n]=df_list
    n+=1
# 将每个聚类标签对应的词语放入一个列表
# 生成聚类标签与对应词列表的dataframe
# Out:
# D:\software\anaconda\envs\nlp\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <ipython-input-22-fe005ca050a2>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   word['word'][n]=df_list

# %%
import pyecharts
from pyecharts.globals import SymbolType
from pyecharts.globals import ThemeType,CurrentConfig 
import collections
from pyecharts.charts import WordCloud
import pyecharts.options as opts 
from pyecharts.charts import Page

page = Page()

for i in range(80):
    label = Labels[i]
    
    text = word['word'][i]
    
    word_counts = collections.Counter(text)
    word_count_topn = word_counts.most_common(50)

    word1 = WordCloud(init_opts=opts.InitOpts(width='600px', height='400px', theme=ThemeType.MACARONS))
    word1.add('词频', data_pair=word_count_topn,
              word_size_range=[15, 108], textstyle_opts=opts.TextStyleOpts(font_family='cursive'),
              shape=SymbolType.DIAMOND)

    word1.set_global_opts(title_opts=opts.TitleOpts('标签%s'%(label)),
                          toolbox_opts=pyecharts.options.ToolboxOpts(is_show=False),
                          tooltip_opts=opts.TooltipOpts(is_show=True, background_color='red', border_color='yellow'))

    page.add(word1)

#page.render('名词_聚类80.html')
page.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min', 'macarons':'https://assets.pyecharts.org/assets/themes/macarons'
#         }
#     });
# </script>
#
#         <div id="3800882ca8c14d43a2e78aae8e8fd837" style="width:600px; height:400px;"></div>
#         <div id="774952ff004b405988d9809fc222e518" style="width:600px; height:400px;"></div>
#         <div id="bc32f9db76c5494dbb8ded77100565d1" style="width:600px; height:400px;"></div>
#         <div id="174231b7bd0342db91566a4da4507fa1" style="width:600px; height:400px;"></div>
#         <div id="d4d1a029974a4e6795e6f984851c5b63" style="width:600px; height:400px;"></div>
#         <div id="c43dd96515864543a84516253086efe7" style="width:600px; height:400px;"></div>
#         <div id="aba4a08c9d974c99a1ae0d8aaa20b0f9" style="width:600px; height:400px;"></div>
# ...
